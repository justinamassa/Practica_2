# %%
import sys
sys.path.append('../src')

from costo_envio import calcular_costo

# %%
peso = float(input("Ingrese el peso del paquete (kg): "))
zona = input("Ingrese la zona de destino (local/regional/nacional): ").lower()

costo = calcular_costo(peso, zona)

if costo is None:
    print(f"Zona no válida. Las zonas disponibles son: local, regional, nacional.")
else:
    print(f"Costo de envío: ${costo}")
